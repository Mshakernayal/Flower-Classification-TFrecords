# %%
import tensorflow as tf
print("TPU devices:", tf.config.experimental.list_logical_devices('TPU'))
# Out:
# TPU devices: [LogicalDevice(name='/device:TPU:0', device_type='TPU'), LogicalDevice(name='/device:TPU:1', device_type='TPU'), LogicalDevice(name='/device:TPU:2', device_type='TPU'), LogicalDevice(name='/device:TPU:3', device_type='TPU'), LogicalDevice(name='/device:TPU:4', device_type='TPU'), LogicalDevice(name='/device:TPU:5', device_type='TPU'), LogicalDevice(name='/device:TPU:6', device_type='TPU'), LogicalDevice(name='/device:TPU:7', device_type='TPU')]

# %%
import tensorflow as tf

# Create a TPU strategy
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

# with strategy.scope():
#     # Your model and training code here
#     model = tf.keras.Sequential([...])
#     model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#     model.fit(training_data, training_labels, epochs=10)
# Out:
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1731507682.407993      13 common_lib.cc:798] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="local"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:479
# D1113 14:21:22.416494360      13 config.cc:196]                        gRPC EXPERIMENT call_status_override_on_cancellation   OFF (default:OFF)
# D1113 14:21:22.416511442      13 config.cc:196]                        gRPC EXPERIMENT call_v3                                OFF (default:OFF)
# D1113 14:21:22.416515080      13 config.cc:196]                        gRPC EXPERIMENT canary_client_privacy                  ON  (default:ON)
# D1113 14:21:22.416517765      13 config.cc:196]                        gRPC EXPERIMENT capture_base_context                   ON  (default:ON)
# D1113 14:21:22.416520536      13 config.cc:196]                        gRPC EXPERIMENT client_idleness                        ON  (default:ON)
# D1113 14:21:22.416523357      13 config.cc:196]                        gRPC EXPERIMENT client_privacy                         ON  (default:ON)
# D1113 14:21:22.416525945      13 config.cc:196]                        gRPC EXPERIMENT dapper_request_wire_size               OFF (default:OFF)
# D1113 14:21:22.416528433      13 config.cc:196]                        gRPC EXPERIMENT empty_experiment                       OFF (default:OFF)
# D1113 14:21:22.416530881      13 config.cc:196]                        gRPC EXPERIMENT event_engine_client                    OFF (default:OFF)
# D1113 14:21:22.416533325      13 config.cc:196]                        gRPC EXPERIMENT event_engine_dns                       ON  (default:ON)
# D1113 14:21:22.416535805      13 config.cc:196]                        gRPC EXPERIMENT event_engine_listener                  ON  (default:ON)
# D1113 14:21:22.416538313      13 config.cc:196]                        gRPC EXPERIMENT free_large_allocator                   OFF (default:OFF)
# D1113 14:21:22.416540797      13 config.cc:196]                        gRPC EXPERIMENT google_no_envelope_resolver            OFF (default:OFF)
# D1113 14:21:22.416543253      13 config.cc:196]                        gRPC EXPERIMENT http2_stats_fix                        OFF (default:OFF)
# D1113 14:21:22.416545722      13 config.cc:196]                        gRPC EXPERIMENT keepalive_fix                          OFF (default:OFF)
# D1113 14:21:22.416548207      13 config.cc:196]                        gRPC EXPERIMENT keepalive_server_fix                   ON  (default:ON)
# D1113 14:21:22.416550842      13 config.cc:196]                        gRPC EXPERIMENT loas_do_not_prefer_rekey_next_protocol OFF (default:OFF)
# D1113 14:21:22.416553368      13 config.cc:196]                        gRPC EXPERIMENT loas_prod_to_cloud_prefer_pfs_ciphers  OFF (default:OFF)
# D1113 14:21:22.416555866      13 config.cc:196]                        gRPC EXPERIMENT monitoring_experiment                  ON  (default:ON)
# D1113 14:21:22.416558395      13 config.cc:196]                        gRPC EXPERIMENT multiping                              OFF (default:OFF)
# D1113 14:21:22.416560865      13 config.cc:196]                        gRPC EXPERIMENT peer_state_based_framing               OFF (default:OFF)
# D1113 14:21:22.416563380      13 config.cc:196]                        gRPC EXPERIMENT pending_queue_cap                      ON  (default:ON)
# D1113 14:21:22.416565936      13 config.cc:196]                        gRPC EXPERIMENT pick_first_happy_eyeballs              ON  (default:ON)
# D1113 14:21:22.416568451      13 config.cc:196]                        gRPC EXPERIMENT promise_based_client_call              OFF (default:OFF)
# D1113 14:21:22.416570860      13 config.cc:196]                        gRPC EXPERIMENT promise_based_inproc_transport         OFF (default:OFF)
# D1113 14:21:22.416573351      13 config.cc:196]                        gRPC EXPERIMENT promise_based_server_call              OFF (default:OFF)
# D1113 14:21:22.416575898      13 config.cc:196]                        gRPC EXPERIMENT registered_method_lookup_in_transport  ON  (default:ON)
# D1113 14:21:22.416578416      13 config.cc:196]                        gRPC EXPERIMENT rfc_max_concurrent_streams             ON  (default:ON)
# D1113 14:21:22.416580992      13 config.cc:196]                        gRPC EXPERIMENT round_robin_delegate_to_pick_first     ON  (default:ON)
# D1113 14:21:22.416584806      13 config.cc:196]                        gRPC EXPERIMENT rstpit                                 OFF (default:OFF)
# D1113 14:21:22.416587591      13 config.cc:196]                        gRPC EXPERIMENT schedule_cancellation_over_write       OFF (default:OFF)
# D1113 14:21:22.416590687      13 config.cc:196]                        gRPC EXPERIMENT server_privacy                         ON  (default:ON)
# D1113 14:21:22.416593561      13 config.cc:196]                        gRPC EXPERIMENT tcp_frame_size_tuning                  OFF (default:OFF)
# D1113 14:21:22.416596151      13 config.cc:196]                        gRPC EXPERIMENT tcp_rcv_lowat                          OFF (default:OFF)
# D1113 14:21:22.416598613      13 config.cc:196]                        gRPC EXPERIMENT trace_record_callops                   OFF (default:OFF)
# D1113 14:21:22.416601139      13 config.cc:196]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size    OFF (default:OFF)
# D1113 14:21:22.416603543      13 config.cc:196]                        gRPC EXPERIMENT v3_backend_metric_filter               OFF (default:OFF)
# D1113 14:21:22.416606014      13 config.cc:196]                        gRPC EXPERIMENT v3_channel_idle_filters                ON  (default:ON)
# D1113 14:21:22.416608538      13 config.cc:196]                        gRPC EXPERIMENT v3_compression_filter                  ON  (default:ON)
# D1113 14:21:22.416611034      13 config.cc:196]                        gRPC EXPERIMENT v3_server_auth_filter                  OFF (default:OFF)
# D1113 14:21:22.416613492      13 config.cc:196]                        gRPC EXPERIMENT work_serializer_clears_time_cache      OFF (default:OFF)
# D1113 14:21:22.416615923      13 config.cc:196]                        gRPC EXPERIMENT work_serializer_dispatch               OFF (default:OFF)
# D1113 14:21:22.416618448      13 config.cc:196]                        gRPC EXPERIMENT write_size_cap                         ON  (default:ON)
# D1113 14:21:22.416620940      13 config.cc:196]                        gRPC EXPERIMENT write_size_policy                      ON  (default:ON)
# D1113 14:21:22.416623469      13 config.cc:196]                        gRPC EXPERIMENT wrr_delegate_to_pick_first             ON  (default:ON)
# I1113 14:21:22.416796999      13 ev_epoll1_linux.cc:123]               grpc epoll fd: 59
# D1113 14:21:22.416809862      13 ev_posix.cc:113]                      Using polling engine: epoll1
# D1113 14:21:22.428102327      13 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D1113 14:21:22.428113576      13 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D1113 14:21:22.428121879      13 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D1113 14:21:22.428125339      13 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D1113 14:21:22.428128775      13 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D1113 14:21:22.428131922      13 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin"
# D1113 14:21:22.428170565      13 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D1113 14:21:22.428183791      13 dns_resolver_plugin.cc:43]            Using EventEngine dns resolver
# D1113 14:21:22.428204476      13 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D1113 14:21:22.428227672      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D1113 14:21:22.428235828      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D1113 14:21:22.428239223      13 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D1113 14:21:22.428243627      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D1113 14:21:22.428247228      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D1113 14:21:22.428250653      13 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D1113 14:21:22.428254075      13 certificate_provider_registry.cc:33]  registering certificate provider factory for "file_watcher"
# D1113 14:21:22.428296897      13 channel_init.cc:157]                  Filter server-auth not registered, but is referenced in the after clause of grpc-server-authz when building channel stack SERVER_CHANNEL
# I1113 14:21:22.429837911      13 ev_epoll1_linux.cc:359]               grpc epoll fd: 61
# I1113 14:21:22.430934881      13 tcp_socket_utils.cc:689]              Disabling AF_INET6 sockets because ::1 is not available.
# I1113 14:21:22.448343447     101 socket_utils_common_posix.cc:452]     Disabling AF_INET6 sockets because ::1 is not available.
# I1113 14:21:22.448395749     101 socket_utils_common_posix.cc:379]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E1113 14:21:22.453890868      13 oauth2_credentials.cc:238]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {created_time:"2024-11-13T14:21:22.453876135+00:00", grpc_status:2}
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731507694.718500      13 service.cc:145] XLA service 0x5a06c466e2a0 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731507694.718563      13 service.cc:153]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1731507694.718568      13 service.cc:153]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1731507694.718571      13 service.cc:153]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1731507694.718574      13 service.cc:153]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1731507694.718577      13 service.cc:153]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1731507694.718579      13 service.cc:153]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1731507694.718582      13 service.cc:153]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1731507694.718585      13 service.cc:153]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)

# %%
import math, re, os
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from kaggle_datasets import KaggleDatasets
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
from tensorflow.keras.applications import ResNet50V2,ResNet101V2,ResNet152V2,DenseNet201
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.16.1

# %%
AUTO = tf.data.experimental.AUTOTUNE

# Data access
GCS_DS_PATH = '/kaggle/input/flower-classification-with-tpus'

# Configuration
IMAGE_SIZE = [512, 512]
EPOCHS = 25
BATCH_SIZE = 16 * strategy.num_replicas_in_sync

# %%
GCS_PATH_SELECT = { # available image sizes
    192: GCS_DS_PATH + '/tfrecords-jpeg-192x192',
    224: GCS_DS_PATH + '/tfrecords-jpeg-224x224',
    331: GCS_DS_PATH + '/tfrecords-jpeg-331x331',
    512: GCS_DS_PATH + '/tfrecords-jpeg-512x512'
}
GCS_PATH = GCS_PATH_SELECT[IMAGE_SIZE[0]]

TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train/*.tfrec')
VALIDATION_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/val/*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test/*.tfrec')

# %%
CLASSES = ['pink primrose',    'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea',     'wild geranium',     'tiger lily',           'moon orchid',              'bird of paradise', 'monkshood',        'globe thistle',         # 00 - 09
           'snapdragon',       "colt's foot",               'king protea',      'spear thistle', 'yellow iris',       'globe-flower',         'purple coneflower',        'peruvian lily',    'balloon flower',   'giant white arum lily', # 10 - 19
           'fire lily',        'pincushion flower',         'fritillary',       'red ginger',    'grape hyacinth',    'corn poppy',           'prince of wales feathers', 'stemless gentian', 'artichoke',        'sweet william',         # 20 - 29
           'carnation',        'garden phlox',              'love in the mist', 'cosmos',        'alpine sea holly',  'ruby-lipped cattleya', 'cape flower',              'great masterwort', 'siam tulip',       'lenten rose',           # 30 - 39
           'barberton daisy',  'daffodil',                  'sword lily',       'poinsettia',    'bolero deep blue',  'wallflower',           'marigold',                 'buttercup',        'daisy',            'common dandelion',      # 40 - 49
           'petunia',          'wild pansy',                'primula',          'sunflower',     'lilac hibiscus',    'bishop of llandaff',   'gaura',                    'geranium',         'orange dahlia',    'pink-yellow dahlia',    # 50 - 59
           'cautleya spicata', 'japanese anemone',          'black-eyed susan', 'silverbush',    'californian poppy', 'osteospermum',         'spring crocus',            'iris',             'windflower',       'tree poppy',            # 60 - 69
           'gazania',          'azalea',                    'water lily',       'rose',          'thorn apple',       'morning glory',        'passion flower',           'lotus',            'toad lily',        'anthurium',             # 70 - 79
           'frangipani',       'clematis',                  'hibiscus',         'columbine',     'desert-rose',       'tree mallow',          'magnolia',                 'cyclamen ',        'watercress',       'canna lily',            # 80 - 89
           'hippeastrum ',     'bee balm',                  'pink quill',       'foxglove',      'bougainvillea',     'camellia',             'mallow',                   'mexican petunia',  'bromelia',         'blanket flower',        # 90 - 99
           'trumpet creeper',  'blackberry lily',           'common tulip',     'wild rose']                                                                                                                                               # 100 - 102

# %%
# 1.parse serialized TFRecord to a structure (dict)
# 2.decode TFrecords from the structre
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3) 
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), 
        "class": tf.io.FixedLenFeature([], tf.int64),  
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs

def read_unlabeled_tfrecord(example):
    UNLABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "id": tf.io.FixedLenFeature([], tf.string),  # shape [] means single element
        # class is missing, this competitions's challenge is to predict flower classes for the test dataset
    }
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    idnum = example['id']
    return image, idnum # returns a dataset of image(s)

def load_dataset(filenames, labeled=True, ordered=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord if labeled else read_unlabeled_tfrecord, num_parallel_calls=AUTO)
    # returns a dataset of (image, label) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset

def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES, labeled=True)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(ordered=False):
    dataset = load_dataset(VALIDATION_FILENAMES, labeled=True, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_test_dataset(ordered=False):
    dataset = load_dataset(TEST_FILENAMES, labeled=False, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def count_data_items(filenames):
    # the number of data items is written in the name of the .tfrec files, i.e. flowers00-230.tfrec = 230 data items
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

# %%
def lrfn(epoch):
    LR_START = 0.00001
    LR_MAX = 0.00005 * strategy.num_replicas_in_sync
    LR_MIN = 0.00001
    LR_RAMPUP_EPOCHS = 5
    LR_SUSTAIN_EPOCHS = 0
    LR_EXP_DECAY = .8
    
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr

# %%
def freeze(model):
    for layer in model.layers:
        layer.trainable = False

def unfreeze(model):
    for layer in model.layers:
        layer.trainable = True

# %%
NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALIDATION_FILENAMES)
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)
STEPS_PER_EPOCH = (NUM_TRAINING_IMAGES + NUM_VALIDATION_IMAGES) // BATCH_SIZE
print('Dataset: {} training images, {} unlabeled test images'.format(NUM_TRAINING_IMAGES+NUM_VALIDATION_IMAGES, NUM_TEST_IMAGES))
# Out:
# Dataset: 16465 training images, 7382 unlabeled test images

# %%
# Need this line so Google will recite some incantations
# for Turing to magically load the model onto the TPU
with strategy.scope():
    rnet = DenseNet201(
        input_shape=(512, 512, 3),
        weights='imagenet',
        include_top=False
    )

    freeze(rnet)
    
    model = tf.keras.Sequential([
        rnet,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(len(CLASSES), activation='softmax')
    ])
        
    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss = 'sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    print(model.summary())

    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=1)

    history = model.fit(
        get_training_dataset(), 
        steps_per_epoch=STEPS_PER_EPOCH,
        epochs=EPOCHS, 
        validation_data=get_validation_dataset(),
        callbacks=[lr_schedule]
    )
# Out:
# I0000 00:00:1731507701.605091      13 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet201 (Functional)        │ (None, 16, 16, 1920)   │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 104)            │       199,784 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,521,768 (70.65 MB)
#  Trainable params: 199,784 (780.41 KB)
#  Non-trainable params: 18,321,984 (69.89 MB)
# None
#
# Epoch 1: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 1/25
# 2024-11-13 14:22:38.715057: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node StatefulPartitionedCall.
# I0000 00:00:1731507761.052112     814 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(807a72308dcd577d:0:0), session_name()
# I0000 00:00:1731507778.452389     814 tpu_compile_op_common.cc:245] Compilation of 807a72308dcd577d:0:0 with session name  took 17.400224507s and succeeded
# I0000 00:00:1731507778.488475     814 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(807a72308dcd577d:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_6137470441654377925", property.function_library_fingerprint = 18103747846283600412, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "16,512,512,3,;16,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731507778.488542     814 tpu_compilation_cache_interface.cc:541] After adding entry for key 807a72308dcd577d:0:0 with session_name  cache is 1 entries (90503679 bytes),  marked for eviction 0 entries (0 bytes).
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 4.7779 - sparse_categorical_accuracy: 0.0097
# 2024-11-13 14:24:15.606035: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add/ReadVariableOp.
# I0000 00:00:1731507857.959500     837 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(8d893d2284d93a64:0:0), session_name()
# I0000 00:00:1731507874.247808     837 tpu_compile_op_common.cc:245] Compilation of 8d893d2284d93a64:0:0 with session name  took 16.288259888s and succeeded
# I0000 00:00:1731507874.289220     837 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(8d893d2284d93a64:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_13682269307469169196", property.function_library_fingerprint = 13550839252456274722, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "16,512,512,3,;16,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1731507874.289260     837 tpu_compilation_cache_interface.cc:541] After adding entry for key 8d893d2284d93a64:0:0 with session_name  cache is 2 entries (180175979 bytes),  marked for eviction 0 entries (0 bytes).
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 140s 855ms/step - loss: 4.7775 - sparse_categorical_accuracy: 0.0097 - val_loss: 4.5981 - val_sparse_categorical_accuracy: 0.0086 - learning_rate: 1.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 8.8e-05.
# Epoch 2/25
# /usr/local/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 4.3366 - sparse_categorical_accuracy: 0.0435 - val_loss: 3.9318 - val_sparse_categorical_accuracy: 0.1013 - learning_rate: 8.8000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.000166.
# Epoch 3/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 654ms/step - loss: 3.7571 - sparse_categorical_accuracy: 0.1439 - val_loss: 3.4140 - val_sparse_categorical_accuracy: 0.2220 - learning_rate: 1.6600e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000244.
# Epoch 4/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 83s 650ms/step - loss: 3.1965 - sparse_categorical_accuracy: 0.3036 - val_loss: 2.8739 - val_sparse_categorical_accuracy: 0.4289 - learning_rate: 2.4400e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.000322.
# Epoch 5/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 661ms/step - loss: 2.6080 - sparse_categorical_accuracy: 0.4710 - val_loss: 2.4043 - val_sparse_categorical_accuracy: 0.5409 - learning_rate: 3.2200e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 6/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 662ms/step - loss: 2.1249 - sparse_categorical_accuracy: 0.5893 - val_loss: 2.0279 - val_sparse_categorical_accuracy: 0.6013 - learning_rate: 4.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.000322.
# Epoch 7/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 658ms/step - loss: 1.7594 - sparse_categorical_accuracy: 0.6668 - val_loss: 1.7913 - val_sparse_categorical_accuracy: 0.6444 - learning_rate: 3.2200e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0002596000000000001.
# Epoch 8/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 660ms/step - loss: 1.5560 - sparse_categorical_accuracy: 0.7084 - val_loss: 1.6594 - val_sparse_categorical_accuracy: 0.6724 - learning_rate: 2.5960e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00020968000000000004.
# Epoch 9/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 661ms/step - loss: 1.4087 - sparse_categorical_accuracy: 0.7320 - val_loss: 1.5679 - val_sparse_categorical_accuracy: 0.7026 - learning_rate: 2.0968e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00016974400000000002.
# Epoch 10/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 661ms/step - loss: 1.3280 - sparse_categorical_accuracy: 0.7522 - val_loss: 1.4980 - val_sparse_categorical_accuracy: 0.7004 - learning_rate: 1.6974e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.00013779520000000003.
# Epoch 11/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 1.2635 - sparse_categorical_accuracy: 0.7662 - val_loss: 1.4452 - val_sparse_categorical_accuracy: 0.7155 - learning_rate: 1.3780e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.00011223616000000004.
# Epoch 12/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 660ms/step - loss: 1.1960 - sparse_categorical_accuracy: 0.7820 - val_loss: 1.4077 - val_sparse_categorical_accuracy: 0.7198 - learning_rate: 1.1224e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.178892800000003e-05.
# Epoch 13/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 658ms/step - loss: 1.1574 - sparse_categorical_accuracy: 0.7882 - val_loss: 1.3773 - val_sparse_categorical_accuracy: 0.7241 - learning_rate: 9.1789e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 7.543114240000003e-05.
# Epoch 14/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 661ms/step - loss: 1.1329 - sparse_categorical_accuracy: 0.7917 - val_loss: 1.3540 - val_sparse_categorical_accuracy: 0.7349 - learning_rate: 7.5431e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 6.234491392000002e-05.
# Epoch 15/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 663ms/step - loss: 1.1121 - sparse_categorical_accuracy: 0.7981 - val_loss: 1.3362 - val_sparse_categorical_accuracy: 0.7349 - learning_rate: 6.2345e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 5.1875931136000024e-05.
# Epoch 16/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 656ms/step - loss: 1.0755 - sparse_categorical_accuracy: 0.8023 - val_loss: 1.3190 - val_sparse_categorical_accuracy: 0.7349 - learning_rate: 5.1876e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.3500744908800015e-05.
# Epoch 17/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 1.0680 - sparse_categorical_accuracy: 0.8036 - val_loss: 1.3056 - val_sparse_categorical_accuracy: 0.7371 - learning_rate: 4.3501e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 3.6800595927040014e-05.
# Epoch 18/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 1.0554 - sparse_categorical_accuracy: 0.8041 - val_loss: 1.2949 - val_sparse_categorical_accuracy: 0.7392 - learning_rate: 3.6801e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 3.1440476741632015e-05.
# Epoch 19/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 668ms/step - loss: 1.0524 - sparse_categorical_accuracy: 0.8099 - val_loss: 1.2861 - val_sparse_categorical_accuracy: 0.7435 - learning_rate: 3.1440e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 2.7152381393305616e-05.
# Epoch 20/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 659ms/step - loss: 1.0309 - sparse_categorical_accuracy: 0.8115 - val_loss: 1.2784 - val_sparse_categorical_accuracy: 0.7392 - learning_rate: 2.7152e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 2.3721905114644494e-05.
# Epoch 21/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 666ms/step - loss: 1.0409 - sparse_categorical_accuracy: 0.8111 - val_loss: 1.2716 - val_sparse_categorical_accuracy: 0.7392 - learning_rate: 2.3722e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 2.0977524091715595e-05.
# Epoch 22/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 662ms/step - loss: 1.0168 - sparse_categorical_accuracy: 0.8155 - val_loss: 1.2651 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 2.0978e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 1.8782019273372477e-05.
# Epoch 23/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 85s 664ms/step - loss: 1.0083 - sparse_categorical_accuracy: 0.8179 - val_loss: 1.2598 - val_sparse_categorical_accuracy: 0.7478 - learning_rate: 1.8782e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 1.702561541869798e-05.
# Epoch 24/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 1.0073 - sparse_categorical_accuracy: 0.8134 - val_loss: 1.2551 - val_sparse_categorical_accuracy: 0.7522 - learning_rate: 1.7026e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.5620492334958385e-05.
# Epoch 25/25
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 84s 655ms/step - loss: 1.0048 - sparse_categorical_accuracy: 0.8161 - val_loss: 1.2504 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 1.5620e-05

# %%
_, axs = plt.subplots(2, 1, figsize=(12, 12))
plt.tight_layout()

axs[0].plot(history.history['loss'], color = 'b', label = 'training loss')
axs[0].plot(history.history['val_loss'], color = 'r', label = 'validation loss')
axs[0].legend()

axs[1].plot(history.history['sparse_categorical_accuracy'], color='b', label = 'traning accuracy')
axs[1].plot(history.history['val_sparse_categorical_accuracy'], color='r', label = 'validation accuracy')
axs[1].legend()

loss = np.min(history.history['loss'])
val_loss = np.min(history.history['val_loss'])
acc = np.max(history.history['sparse_categorical_accuracy'])
val_acc = np.max(history.history['val_sparse_categorical_accuracy'])

print(loss, val_loss, acc, val_acc)
# Out:
# 0.9682297110557556 1.2504298686981201 0.82861328125 0.7521551847457886
